# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# planilha_geral = pd.read_excel(r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero.xlsx", 0)
def f(Ano):
    planilha_geral_2015 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2015.xlsx", 0)
    planilha_geral_2016 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2016.xlsx", 0)
    planilha_geral_2017 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2017.xlsx", 0)
    planilha_geral_2018 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2018.xlsx", 0)
    planilha_geral_2019 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2019.xlsx", 0)
    # /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
    planilha_empresas_2015 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2015.xlsx", 2)
    planilha_empresas_2016 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2016.xlsx", 2)
    planilha_empresas_2017 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2017.xlsx", 2)
    planilha_empresas_2018 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2018.xlsx", 2)
    planilha_empresas_2019 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2019.xlsx", 2)
    # /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
    planilha_aeroportos_origem_2015 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2015.xlsx", 4)
    planilha_aeroportos_origem_2016 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2016.xlsx", 4)
    planilha_aeroportos_origem_2017 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2017.xlsx", 4)
    planilha_aeroportos_origem_2018 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2018.xlsx", 4)
    planilha_aeroportos_origem_2019 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2019.xlsx", 4)
    # /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
    planilha_aeroportos_destino_2015 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2015.xlsx", 6)
    planilha_aeroportos_destino_2016 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2016.xlsx", 6)
    planilha_aeroportos_destino_2017 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2017.xlsx", 6)
    planilha_aeroportos_destino_2018 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2018.xlsx", 6)
    planilha_aeroportos_destino_2019 = pd.read_excel(
        r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero2019.xlsx", 6)

    if (Ano == 2015):
        planilha_geral = planilha_geral_2015
        planilha_empresas = planilha_empresas_2015
        planilha_aeroportos_origem = planilha_aeroportos_origem_2015
        planilha_aeroportos_destino = planilha_aeroportos_destino_2015

    elif (Ano == 2016):
        planilha_geral = planilha_geral_2016
        planilha_empresas = planilha_empresas_2016
        planilha_aeroportos_origem = planilha_aeroportos_origem_2016
        planilha_aeroportos_destino = planilha_aeroportos_destino_2016

    elif (Ano == 2017):
        planilha_geral = planilha_geral_2017
        planilha_empresas = planilha_empresas_2017
        planilha_aeroportos_origem = planilha_aeroportos_origem_2017
        planilha_aeroportos_destino = planilha_aeroportos_destino_2017

    elif (Ano == 2018):
        planilha_geral = planilha_geral_2018
        planilha_empresas = planilha_empresas_2018
        planilha_aeroportos_origem = planilha_aeroportos_origem_2018
        planilha_aeroportos_destino = planilha_aeroportos_destino_2018

    elif (Ano == 2019):
        planilha_geral = planilha_geral_2019
        planilha_empresas = planilha_empresas_2019
        planilha_aeroportos_origem = planilha_aeroportos_origem_2019
        planilha_aeroportos_destino = planilha_aeroportos_destino_2019

    '''▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬'''
    fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20, 12))
    fig.tight_layout(pad=3.0)

    '''▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬ PLOTANDO GRÁFICO - GERAL ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬'''
    # planilha_geral = pd.read_excel(r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero.xlsx", 0)
    col_total = planilha_geral['Programado']
    col_realiz = planilha_geral['Realizados']
    realizados = col_realiz.iloc[0]
    cancelados = col_total[0] - realizados
    string_realiz = (str(realizados) + ' Realizados')
    string_cancel = (str(cancelados) + ' Cancelados')

    cores = ['green', 'darkblue']
    recipe = [string_realiz, string_cancel]
    data = [float(x.split()[0]) for x in recipe]
    ingredients = [x.split()[-1] for x in recipe]

    def func(pct, allvals):
        absolute = int(pct / 100. * np.sum(allvals))
        return "{:.1f}%\n({:d} voos)".format(pct, absolute)

    wedges, texts, autotexts = ax[0, 0].pie(data, autopct=lambda pct: func(pct, data),
                                            textprops=dict(color="w"), colors=cores)
    ax[0, 0].legend(wedges, ingredients,
                    # title="Voos",
                    loc="center left",
                    bbox_to_anchor=(1, 0, 0.5, 1))

    ax[0, 0].set_title('Total de voos em ' + str(Ano), fontweight="bold", size=14)

    '''▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬ PLOTANDO GRÁFICO - EMPRESAS ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬'''
    # planilha_empresas = pd.read_excel(r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero.xlsx", 2)
    empresas = planilha_empresas['Empresa']
    porc_real = planilha_empresas['% Realizados']
    porc_canc = planilha_empresas['% Cancelados']

    labels = empresas
    x = np.arange(len(labels))  # the label locations
    width = 0.20  # the width of the bars

    rects1_emp = ax[0, 1].bar(x - width / 2, porc_real, width, label='Realizados')
    rects2_emp = ax[0, 1].bar(x + width / 2, porc_canc, width, label='Cancelados')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax[0, 1].set_ylabel('Porcentagem')
    ax[0, 1].set_title('Taxa de Voos(%) por Empresa - ' + str(Ano), fontweight="bold", size=14)
    ax[0, 1].set_xticks(x)
    ax[0, 1].set_xticklabels(labels)

    ax[0, 1].legend()

    def autolabel_emp(rects):
        """Attach a text label above each bar in rects, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax[0, 1].annotate('{}'.format(height),
                              xy=(rect.get_x() + rect.get_width() / 2, height),
                              xytext=(0, 2.5),  # 3 points vertical offset
                              textcoords="offset points",
                              ha='center', va='bottom')

    autolabel_emp(rects1_emp)
    autolabel_emp(rects2_emp)

    fig.tight_layout(pad=3.0)
    # ---------------------------------------------------------------------------------------
    '''▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬ PLOTANDO GRÁFICO AEROPORTOS - ORIGEM ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬'''
    # planilha_aeroportos_origem = pd.read_excel(r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero.xlsx", 4)
    aeroportos_part = planilha_aeroportos_origem['Aeroporto']
    # aero_part_voos_prog = planilha_aeroportos_origem['Programados']
    aero_part_porc_real = planilha_aeroportos_origem['% Realizados']
    aero_part_porc_canc = planilha_aeroportos_origem['% Cancelados']

    labels = aeroportos_part
    x = np.arange(len(labels))  # the label locations
    width = 0.18  # the width of the bars

    rects1_aero_orig = ax[1, 0].bar(x - width / 2, aero_part_porc_real, width, label='Realizados', color='deepskyblue',edgecolor='black')
    rects2_aero_orig = ax[1, 0].bar(x + width / 2, aero_part_porc_canc, width, label='Cancelados', color='gray')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax[1, 0].set_ylabel('Porcentagem')
    ax[1, 0].set_title('Taxa de Voos(%) por Aeroportos de Origem - ' + str(Ano), weight='bold', size=14)
    ax[1, 0].set_xticks(x)
    ax[1, 0].set_xticklabels(labels)

    ax[1, 0].legend()

    def autolabel_aero_orig(rects, x_aero):
        """Attach a text label above each bar in rects, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax[x_aero].annotate('{}'.format(height),
                                xy=(rect.get_x() + rect.get_width() / 2, height),
                                xytext=(0, 2.5),  # 3 points vertical offset
                                textcoords="offset points",
                                ha='center', va='bottom')

    autolabel_aero_orig(rects1_aero_orig, (1, 0))
    autolabel_aero_orig(rects2_aero_orig, (1, 0))

    fig.tight_layout(pad=3.0)

    '''▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬ PLOTANDO GRÁFICO AEROPORTOS - DESTINO ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬'''
    # planilha_aeroportos_destino = pd.read_excel(r"C:\Users\Dragonous\Documents\Pycharm projects\Projeto Eng Soft\Infraero.xlsx", 6)
    aeroportos_dest = planilha_aeroportos_destino['Destino']
    # aero_part_voos_prog = planilha_aeroportos_destino['Programados']
    aero_dest_porc_real = planilha_aeroportos_destino['% Realizados']
    aero_dest_porc_canc = planilha_aeroportos_destino['% Cancelados']

    labels = aeroportos_dest
    x = np.arange(len(labels))  # the label locations
    width = 0.18  # the width of the bars

    # fig, ax = plt.subplots()
    rects1 = ax[1, 1].bar(x - width / 2, aero_dest_porc_real, width, label='Realizados', color='lightblue',
                          edgecolor='black')
    rects2 = ax[1, 1].bar(x + width / 2, aero_dest_porc_canc, width, label='Cancelados', color='lightcoral')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax[1, 1].set_ylabel('Porcentagem')
    ax[1, 1].set_title('Taxa de Voos(%) por Aeroportos de Destino - ' + str(Ano), fontweight="bold", size=14)
    ax[1, 1].set_xticks(x)
    ax[1, 1].set_xticklabels(labels)

    ax[1, 1].legend()

    def autolabel(rects, x_aero):
        """Attach a text label above each bar in rects, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax[x_aero].annotate('{}'.format(height),
                                xy=(rect.get_x() + rect.get_width() / 2, height),
                                xytext=(0, 2.5),  # 3 points vertical offset
                                textcoords="offset points",
                                ha='center', va='bottom')

    autolabel(rects1, (1, 1))
    autolabel(rects2, (1, 1))

    fig.tight_layout(pad=3.0)
    # -------------------------------------------------------


interact(f, Ano=widgets.IntSlider(min=2015, max=2019, step=1, value=2015, description='Ano: '))
# plt.show()
# Out:
# interactive(children=(IntSlider(value=2015, description='Ano: ', max=2019, min=2015), Output()), _dom_classes=…
# <function __main__.f(Ano)>
